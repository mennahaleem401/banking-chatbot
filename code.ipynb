# %%
import pandas as pd

# Read all CSV files
accounts_df = pd.read_csv('uploads/accounts.csv')
transactions_df = pd.read_csv('uploads/transactions.csv')
users_df = pd.read_csv('uploads/users.csv')
user_financials_df = pd.read_csv('uploads/user_financials.csv')

# Display basic information about each dataset
print("=" * 80)
print("ACCOUNTS DATA")
print("=" * 80)
print(f"Shape: {accounts_df.shape}")
print(f"\nColumns: {accounts_df.columns.tolist()}")
print(f"\nData types:\n{accounts_df.dtypes}")
print(f"\nFirst 5 rows:")
print(accounts_df.head())
print(f"\nSample statistics:")
print(accounts_df.describe())

print("\n" + "=" * 80)
print("TRANSACTIONS DATA")
print("=" * 80)
print(f"Shape: {transactions_df.shape}")
print(f"\nColumns: {transactions_df.columns.tolist()}")
print(f"\nData types:\n{transactions_df.dtypes}")
print(f"\nFirst 5 rows:")
print(transactions_df.head())
print(f"\nSample statistics:")
print(transactions_df.describe())

print("\n" + "=" * 80)
print("USERS DATA")
print("=" * 80)
print(f"Shape: {users_df.shape}")
print(f"\nColumns: {users_df.columns.tolist()}")
print(f"\nData types:\n{users_df.dtypes}")
print(f"\nFirst 5 rows:")
print(users_df.head())

print("\n" + "=" * 80)
print("USER FINANCIALS DATA")
print("=" * 80)
print(f"Shape: {user_financials_df.shape}")
print(f"\nColumns: {user_financials_df.columns.tolist()}")
print(f"\nData types:\n{user_financials_df.dtypes}")
print(f"\nFirst 5 rows:")
print(user_financials_df.head())
print(f"\nSample statistics:")
print(user_financials_df.describe())
# Out:
# ...
# ACCOUNTS DATA
# ...
# Shape: (50, 5)
#
# Columns: ['id', 'userId', 'accountNo', 'accountType', 'balance']
#
# Data types:
# id               int64
# userId           int64
# accountNo       object
# accountType     object
# balance        float64
# dtype: object
#
# First 5 rows:
#    id  userId      accountNo accountType   balance
# 0   1       1  CUR3342331444     Current  59049.25
# 1   2       2  CUR7635473142     Current  22044.06
# 2   3       3  CUR1667779376     Current  95721.31
# 3   4       4  SAV8429141456     Savings  53622.81
# 4   5       5  CUR1298737106     Current  66126.33
#
# Sample statistics:
#              id    userId      balance
# count  50.00000  50.00000     50.00000
# mean   25.50000  25.50000  53884.73180
# std    14.57738  14.57738  28339.72993
# min     1.00000   1.00000    354.57000
# 25%    13.25000  13.25000  29642.28000
# 50%    25.50000  25.50000  59471.85500
# 75%    37.75000  37.75000  79923.72750
# max    50.00000  50.00000  97107.84000
#
# ...
